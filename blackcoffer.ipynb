# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ##START

# %%
inputXL = '/content/Input.xlsx'
df = pd.read_excel(inputXL)
# Out:
#       URL_ID                                                URL
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
# [114 rows x 2 columns]

# %%
Final = {'URL_ID':[],'URL':[],'Title':[],'Article':[]}

for index, row in df.iterrows():
  url_id = row['URL_ID']
  url = row['URL']
  web = requests.get(url).text
  soup = BeautifulSoup(web,'lxml')
  title_element = soup.find('h1',class_='entry-title')
  article_element = soup.find('div', class_='td-post-content')

  if title_element is not None:
    title = title_element.text
  else:
    title = 'NAN'

  if article_element is not None:
    article = article_element.text.replace('\n','')
  else:
    article = 'NAN'

  Final['URL_ID'].append(url_id)
  Final['URL'].append(url)
  Final['Title'].append(title)
  Final['Article'].append(article)

# %%
Final_DF = pd.DataFrame(Final)

# %%
Final_DF
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article
# 0    Telemedicine, the use of technology to diagnos...
# 1    The rise of e-health, or the use of electronic...
# 2    2020 was the year the world was ravaged by the...
# 3    “More gains on quality, affordability and acce...
# 4    “More gains on quality, affordability and acce...
# ..                                                 ...
# 109  Before jumping on the topic I would like to gi...
# 110  As the coronavirus spreads around the world an...
# 111  From Alibaba to Ping An and Google to Ford, co...
# 112  Whenthe British ruled India, many Indiansaccep...
# 113  The business of business is no longer to do ju...
#
# [114 rows x 4 columns]

# %%
import os
path = "/content/scrapped_text_files"
os.makedirs(path, exist_ok=True)

for index, row in Final_DF.iterrows():
    url_id = row['URL_ID']
    article_text = row['Article']

    # Create the filename using the URL ID
    filename = f'{url_id}.txt'

    # Create the full path for saving
    file_path = os.path.join(path, filename)

    # Save the article text to the text file
    with open(file_path, 'w') as file:
        file.write(article_text)

# %%
def from_txt(path, encoding='utf-8'):
  l = []
  with open(path,'r',encoding=encoding) as file:
    for line in file:
      row_data = line.strip()
      l.append(row_data)
  return l

# %%
pos_file = "/content/positive-words.txt"
pos_words = []

neg_file = "/content/negative-words.txt"
neg_words = []

pos_words = from_txt(pos_file,'latin-1')
neg_words = from_txt(neg_file,'latin-1')

# %%
print(len(pos_words))
print(len(neg_words))
# Out:
# 2006
# 4783

# %%
pos_words[0:10:2]
# Out:
# ['a+', 'abounds', 'abundant', 'accessible', 'acclaimed']

# %%
neg_words[0:10:2]
# Out:
# ['2-faced', 'abnormal', 'abominable', 'abominate', 'abort']

# %%
import re

auditor    = "/content/StopWords_Auditor.txt"
currencies = "/content/StopWords_Currencies.txt"
dates      = "/content/StopWords_DatesandNumbers.txt"
generic    = "/content/StopWords_Generic.txt"
genericLong = "/content/StopWords_GenericLong.txt"
geographic = "/content/StopWords_Geographic.txt"
names      = "/content/StopWords_Names.txt"

def edit_stop_word_list(path, encoding='utf-8'):
  # Sample list of words
  words = from_txt(path,encoding)

  # Define a regular expression pattern to match the "word1 | word2" pattern
  p1 = r'^\s*([^\s|]+)'

  # Extract word1 from words with the pattern
  cleaned_words = [re.match(p1, word).group(1) if re.match(p1, word) else word for word in words]

  return cleaned_words

# %%
#stop words

auditor_list      = edit_stop_word_list(auditor,'latin-1')
currencies_list   = edit_stop_word_list(currencies,'latin-1')
dates_list        = edit_stop_word_list(dates,'latin-1')
generic_list      = edit_stop_word_list(generic,'latin-1')
genericLong_list  = edit_stop_word_list(genericLong,'latin-1')
geographic_list   = edit_stop_word_list(geographic,'latin-1')
names_list        = edit_stop_word_list(names,'latin-1')



stop_data = {
    'auditor_list' : auditor_list,
    'currencies_list' : currencies_list,
    'dates_list' : dates_list,
    'generic_list' : generic_list,
    'geographic_list' : geographic_list,
    'names_list' : names_list
}

stop_words = auditor_list + currencies_list + dates_list + generic_list + geographic_list + names_list

# %%
stop_words[0:10:2]
# Out:
# ['ERNST', 'DELOITTE', 'KPMG', 'PRICEWATERHOUSE', 'AFGHANI']

# %%
final_copy = Final_DF.copy()

# %% [markdown]
# ###REMOVE STOPWORDS

# %%
p2 = r'\b(?:' + '|'.join(stop_words) + r')\b'

def remove_stop_word(text,pattern = p2):
  if(text == "NAN"):
    return "NAN"
  #print(pattern)
  return re.sub(pattern, '', text, flags=re.IGNORECASE)

# %%
final_copy['Article'] = final_copy['Article'].apply(remove_stop_word)

# %%
final_copy['Article'][0]
# Out:
# 'Telemedicine,  use  technology  diagnose   patients remotely,   rising  recent years.   advent  - internet  improved video conferencing tools, healthcare providers  increasingly turning  telemedicine  provide care  patients  remote  underserved areas.Telemedicine, using technology  provide healthcare services remotely,  recently gained popularity.  advancements  communication  medical technology,   become increasingly possible  doctors  patients  connect  interact  anywhere   world.   led   rise  telemedicine,    potential  revolutionize   healthcare  delivered.#TelemedicineThe increasing focus  preventative healthcare  also driven  rise  telemedicine.     people become aware   importance  staying healthy,   looking  ways  prevent illness  maintain  health. Telemedicine allows people  monitor  health  get advice  healthcare providers without traveling  a clinic  hospital.Improved access  healthcare:    biggest challenges   healthcare industry   unequal distribution  medical resources,   remote  rural areas lacking access  quality care. Telemedicine  help   gap  allowing patients   underserved areas  connect  healthcare providers worldwide.   give people access  specialized medical care   would otherwise   able  receive, improving  health  overall well-.#HealthcareGreater convenience  flexibility: Telemedicine also offers a level  convenience  flexibility   impossible  traditional - medical visits. Patients  consult   healthcare providers   comfort    homes, saving time    travel.   particularly beneficial  individuals   mobility issues   live  areas  limited access  medical facilities.Reduced healthcare costs:  enabling patients  receive care remotely, telemedicine  help reduce  overall cost  healthcare.    telemedicine visits  generally less expensive  - visits   help prevent  need   costly interventions,   hospitalizations.  a result, telemedicine   potential  make healthcare  affordable  patients  healthcare providers alike.#CostsEnhanced healthcare outcomes: Telemedicine  also improve patients’ quality  care.  allowing healthcare providers  access medical records   important information remotely, telemedicine  help ensure  patients receive   appropriate care   needs.   lead  better health outcomes  a higher quality  life  patients.#EnhancedMore significant job opportunities   healthcare industry like healthcare sector, including  healthcare providers, support staff,  technology experts.   provide a boost  local economies  help  reduce unemployment.#JobsBetter care  chronic conditions: Telemedicine  help patients  chronic conditions  manage  health  effectively, allowing   receive regular check-ups  treatment without  need  travel  distances.   improve  quality  life   individuals  reduce  risk  complications   conditions.Increased flexibility  patients  healthcare providers: Telemedicine allows patients  providers  schedule consultations  times convenient  , improving  overall flexibility   healthcare system.   help  reduce wait times  improve patient satisfaction.Increased accessibility: Telemedicine makes healthcare  accessible  people living  rural  remote areas,     easy access  medical facilities.  telemedicine, patients  consult  doctors  specialists   homes using  phones, computers,   devices.     people   able  get  medical care  need, regardless    live.Reduced costs:     significant benefits  telemedicine     reduce healthcare costs. Patients  avoid  costs  travel, accommodation,  time  work associated  - visits   . Telemedicine  also help reduce  cost  medical procedures,  doctors  remotely monitor patients  provide care without needing hospitalization.Improved health outcomes:  providing patients  access  medical care   comfort    homes, telemedicine  help improve  health outcomes.  example, patients  chronic conditions  use telemedicine  manage  symptoms  reduce  risk  complications. Telemedicine  also help prevent  spread  infectious diseases,  patients  receive care without contacting  people.Increased conv ...

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
# [114 rows x 4 columns]

# %% [markdown]
# ###PUNCTUATION

# %%
import string
pancs = string.punctuation
def remove_punctuations(text,pancs=pancs):
  if(text == "NAN"):
    return "NAN"
  return text.translate(str.maketrans('','',pancs))

# %%
final_copy['After_Punctuation_Article'] = final_copy['Article'].apply(remove_punctuations)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article
# 0    Telemedicine  use  technology  diagnose   pati...
# 1     rise  ehealth   use  electronic   facilitate ...
# 2    2020     world  ravaged   SarsCov2 virus  noto...
# 3    “ gains  quality affordability  accessibility ...
# 4    “ gains  quality affordability  accessibility ...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google   companies around  globe ...
# 112  Whenthe  ruled   Indiansaccepted  work   polic...
# 113   business  business   longer    businessor inc...
#
# [114 rows x 5 columns]

# %% [markdown]
# ###NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ###Word Count and Word length

# %%
def word_char_cout(text):
  if(text == "NAN"):
    return 0
  words = word_tokenize(text)
  return len(words)
final_copy['Word_count'] = final_copy['After_Punctuation_Article'].apply(word_char_cout)

# %%
def avg_word_length(text):
  if(text == "NAN"):
    return 0
  words = word_tokenize(text)
  chars = sum(len (word) for word in words)
  if len(words) > 0:
    return chars/len(words)
  else:
    return 0

final_copy['Avg_word_length'] = final_copy['After_Punctuation_Article'].apply(avg_word_length)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length
# 0           7.570370
# 1           7.699387
# 2           6.877451
# 3           7.020298
# 4           7.020298
# ..               ...
# 109         7.115702
# 110         6.682018
# 111         6.642229
# 112         6.995973
# 113         7.871404
#
# [114 rows x 7 columns]

# %% [markdown]
# ###Positive Negative Polarity Subjectivity

# %%
def pos_neg_score(text):
  if(text == "NAN"):
    return 0,0
  pos_score = 0
  neg_score = 0
  text = text.lower()
  words = word_tokenize(text)
  for i in words:
    if i in pos_words:
      pos_score += 1
    if i in neg_words:
      neg_score += 1
  return pos_score, neg_score

final_copy[['Positive_Score','Negative_score']] = final_copy['After_Punctuation_Article'].apply(pos_neg_score).apply(pd.Series)

# %%
def polarity_subjectivity(df):
  pos = df['Positive_Score']
  neg = df['Negative_score']
  words = df['Word_count']


  polarity = ( pos - neg ) / (( pos + neg) + (0.000001))
  subjectivity = (pos + neg ) / (( words ) + 0.000001)

  return polarity, subjectivity

final_copy['Polarity_Score'],final_copy['Subjectivity_Score'] = polarity_subjectivity(final_copy)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length  Positive_Score  Negative_score  Polarity_Score  \
# 0           7.570370              81              21        0.588235
# 1           7.699387              41              13        0.518519
# 2           6.877451              22              27       -0.102041
# 3           7.020298              41              26        0.223881
# 4           7.020298              41              26        0.223881
# ..               ...             ...             ...             ...
# 109         7.115702               8              26       -0.529412
# 110         6.682018              23              58       -0.432099
# 111         6.642229              86              32        0.457627
# 112         6.995973              26              20        0.130435
# 113         7.871404              51              24        0.360000
#
#      Subjectivity_Score
# 0              0.107937
# 1              0.165644
# 2              0.080065
# 3              0.090663
# 4              0.090663
# ..                  ...
# 109            0.093664
# 110            0.088816
# 111            0.115347
# 112            0.061745
# 113            0.126904
#
# [114 rows x 11 columns]

# %% [markdown]
# ###AVG no. words per sentence and AVG length of sentence

# %%
def avg_len_sentence(text):
  if text == "NAN":
    return 0

  sent = sent_tokenize(text)
  number = len(sent)
  total_sum = sum(len(i) for i in sent)

  return total_sum/number


def avg_no_words(text):
    if text == "NAN":
      return 0
    sent = sent_tokenize(text)
    number = len(sent)
    temp = map(remove_punctuations,sent)
    sent_cleaned = list(temp)
    total_words = sum(len(word_tokenize(i)) for i in sent_cleaned)


    return total_words/number

# %%
final_copy['Avg_Sentence_Length'] = final_copy['Article'].apply(avg_len_sentence)

# %%
final_copy['Avg_No._Words/Sentence'] = final_copy['Article'].apply(avg_no_words)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length  Positive_Score  Negative_score  Polarity_Score  \
# 0           7.570370              81              21        0.588235
# 1           7.699387              41              13        0.518519
# 2           6.877451              22              27       -0.102041
# 3           7.020298              41              26        0.223881
# 4           7.020298              41              26        0.223881
# ..               ...             ...             ...             ...
# 109         7.115702               8              26       -0.529412
# 110         6.682018              23              58       -0.432099
# 111         6.642229              86              32        0.457627
# 112         6.995973              26              20        0.130435
# 113         7.871404              51              24        0.360000
#
#      Subjectivity_Score  Avg_Sentence_Length  Avg_No._Words/Sentence
# 0              0.107937           144.852459               15.491803
# 1              0.165644           136.304348               14.173913
# 2              0.080065            81.538462                9.415385
# 3              0.090663           126.313725               14.490196
# 4              0.090663           126.313725               14.490196
# ..                  ...                  ...                     ...
# 109            0.093664           148.909091               16.500000
# 110            0.088816           236.878788               27.818182
# 111            0.115347           128.686567               15.268657
# 112            0.061745           116.315789               13.122807
# 113            0.126904           157.111111               16.416667
#
# [114 rows x 13 columns]

# %% [markdown]
# ### Complex Word & Syllable

# %%
pip install textstat
# Out:
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.14.0)

# %%
import textstat

def calculate_syllable_and_complex_counts(text):
    if text == "NAN":
      return 0,0
    syllable_count_per_word = textstat.syllable_count(text) / len(word_tokenize(text))

    complex_word_count = sum(1 for word in word_tokenize(text) if textstat.syllable_count(word) > 2)

    return syllable_count_per_word, complex_word_count

final_copy[['syllable_count_per_word','complex_word_count']] = final_copy['After_Punctuation_Article'].apply(calculate_syllable_and_complex_counts).apply(pd.Series)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length  Positive_Score  Negative_score  Polarity_Score  \
# 0           7.570370              81              21        0.588235
# 1           7.699387              41              13        0.518519
# 2           6.877451              22              27       -0.102041
# 3           7.020298              41              26        0.223881
# 4           7.020298              41              26        0.223881
# ..               ...             ...             ...             ...
# 109         7.115702               8              26       -0.529412
# 110         6.682018              23              58       -0.432099
# 111         6.642229              86              32        0.457627
# 112         6.995973              26              20        0.130435
# 113         7.871404              51              24        0.360000
#
#      Subjectivity_Score  Avg_Sentence_Length  Avg_No._Words/Sentence  \
# 0              0.107937           144.852459               15.491803
# 1              0.165644           136.304348               14.173913
# 2              0.080065            81.538462                9.415385
# 3              0.090663           126.313725               14.490196
# 4              0.090663           126.313725               14.490196
# ..                  ...                  ...                     ...
# 109            0.093664           148.909091               16.500000
# 110            0.088816           236.878788               27.818182
# 111            0.115347           128.686567               15.268657
# 112            0.061745           116.315789               13.122807
# 113            0.126904           157.111111               16.416667
#
#      syllable_count_per_word  complex_word_count
# 0                   2.103704               261.0
# 1                   2.343558               126.0
# 2                   2.068627               192.0
# 3                   2.037889               216.0
# 4                   2.037889               216.0
# ..                       ...                 ...
# 109                 2.013774                94.0
# 110                 1.990132               259.0
# 111                 2.014663               310.0
# 112                 2.041611               211.0
# 113                 2.417936               248.0
#
# [114 rows x 15 columns]

# %% [markdown]
# ###Percentage of Complex words and Fog Index

# %%
def percentage_complex_words_and_Fog_index(df):
  complex_word_count = df['complex_word_count']
  word_count = df['Word_count']
  avg_sent_length = df['Avg_Sentence_Length']
  percentage = complex_word_count / word_count
  fog_idx = 0.4 * (avg_sent_length + percentage)
  return percentage, fog_idx

final_copy['Percentage_Of_Complex_word'],final_copy['Fog_index'] = polarity_subjectivity(final_copy)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length  Positive_Score  Negative_score  Polarity_Score  \
# 0           7.570370              81              21        0.588235
# 1           7.699387              41              13        0.518519
# 2           6.877451              22              27       -0.102041
# 3           7.020298              41              26        0.223881
# 4           7.020298              41              26        0.223881
# ..               ...             ...             ...             ...
# 109         7.115702               8              26       -0.529412
# 110         6.682018              23              58       -0.432099
# 111         6.642229              86              32        0.457627
# 112         6.995973              26              20        0.130435
# 113         7.871404              51              24        0.360000
#
#      Subjectivity_Score  Avg_Sentence_Length  Avg_No._Words/Sentence  \
# 0              0.107937           144.852459               15.491803
# 1              0.165644           136.304348               14.173913
# 2              0.080065            81.538462                9.415385
# 3              0.090663           126.313725               14.490196
# 4              0.090663           126.313725               14.490196
# ..                  ...                  ...                     ...
# 109            0.093664           148.909091               16.500000
# 110            0.088816           236.878788               27.818182
# 111            0.115347           128.686567               15.268657
# 112            0.061745           116.315789               13.122807
# 113            0.126904           157.111111               16.416667
#
#      syllable_count_per_word  complex_word_count  Percentage_Of_Complex_word  \
# 0                   2.103704               261.0                    0.588235
# 1                   2.343558               126.0                    0.518519
# 2                   2.068627               192.0                   -0.102041
# 3                   2.037889               216.0                    0.223881
# 4                   2.037889               216.0                    0.223881
# ..                       ...                 ...                         ...
# 109                 2.013774                94.0                   -0.529412
# 110                 1.990132               259.0                   -0.432099
# 111                 2.014663               310.0                    0.457627
# 112                 2.041611               211.0                    0.130435
# 113                 2.417936               248.0                    0.360000
#
#      Fog_index
# 0     0.107937
# 1     0.165644
# 2     0.080065
# 3     0.090663
# 4     0.090663
# ..         ...
# 109   0.093664
# 110   0.088816
# 111   0.115347
# 112   0.061745
# 113   0.126904
#
# [114 rows x 17 columns]

# %% [markdown]
# ###Personal Pronouns

# %%
import re
p3 = r'\b(?:I|we|We|ours|Ours|our|Our|my|My|us)\b'

def Personal_Pronouns_count(text,p3=p3):
    if(text == "NAN"):
      return 0
    matches = re.findall(p3, text)
    return len(matches)

final_copy['Personal_Pronouns'] = final_copy['After_Punctuation_Article'].apply(Personal_Pronouns_count)

# %%
final_copy
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  \
# 0    Telemedicine,  use  technology  diagnose   pat...
# 1     rise  e-health,   use  electronic   facilitat...
# 2    2020     world  ravaged   SarsCov2 virus.  not...
# 3    “ gains  quality, affordability  accessibility...
# 4    “ gains  quality, affordability  accessibility...
# ..                                                 ...
# 109   jumping   topic  would like  give  overview  ...
# 110    coronavirus spreads around  world  countries...
# 111   Alibaba     Google  , companies around  globe...
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...
# 113   business  business   longer    businessor inc...
#
#                              After_Punctuation_Article  Word_count  \
# 0    Telemedicine  use  technology  diagnose   pati...         945
# 1     rise  ehealth   use  electronic   facilitate ...         326
# 2    2020     world  ravaged   SarsCov2 virus  noto...         612
# 3    “ gains  quality affordability  accessibility ...         739
# 4    “ gains  quality affordability  accessibility ...         739
# ..                                                 ...         ...
# 109   jumping   topic  would like  give  overview  ...         363
# 110    coronavirus spreads around  world  countries...         912
# 111   Alibaba     Google   companies around  globe ...        1023
# 112  Whenthe  ruled   Indiansaccepted  work   polic...         745
# 113   business  business   longer    businessor inc...         591
#
#      Avg_word_length  Positive_Score  Negative_score  Polarity_Score  \
# 0           7.570370              81              21        0.588235
# 1           7.699387              41              13        0.518519
# 2           6.877451              22              27       -0.102041
# 3           7.020298              41              26        0.223881
# 4           7.020298              41              26        0.223881
# ..               ...             ...             ...             ...
# 109         7.115702               8              26       -0.529412
# 110         6.682018              23              58       -0.432099
# 111         6.642229              86              32        0.457627
# 112         6.995973              26              20        0.130435
# 113         7.871404              51              24        0.360000
#
#      Subjectivity_Score  Avg_Sentence_Length  Avg_No._Words/Sentence  \
# 0              0.107937           144.852459               15.491803
# 1              0.165644           136.304348               14.173913
# 2              0.080065            81.538462                9.415385
# 3              0.090663           126.313725               14.490196
# 4              0.090663           126.313725               14.490196
# ..                  ...                  ...                     ...
# 109            0.093664           148.909091               16.500000
# 110            0.088816           236.878788               27.818182
# 111            0.115347           128.686567               15.268657
# 112            0.061745           116.315789               13.122807
# 113            0.126904           157.111111               16.416667
#
#      syllable_count_per_word  complex_word_count  Percentage_Of_Complex_word  \
# 0                   2.103704               261.0                    0.588235
# 1                   2.343558               126.0                    0.518519
# 2                   2.068627               192.0                   -0.102041
# 3                   2.037889               216.0                    0.223881
# 4                   2.037889               216.0                    0.223881
# ..                       ...                 ...                         ...
# 109                 2.013774                94.0                   -0.529412
# 110                 1.990132               259.0                   -0.432099
# 111                 2.014663               310.0                    0.457627
# 112                 2.041611               211.0                    0.130435
# 113                 2.417936               248.0                    0.360000
#
#      Fog_index  Personal_Pronouns
# 0     0.107937                  0
# 1     0.165644                  0
# 2     0.080065                  0
# 3     0.090663                  0
# 4     0.090663                  0
# ..         ...                ...
# 109   0.093664                  0
# 110   0.088816                  0
# 111   0.115347                  0
# 112   0.061745                  1
# 113   0.126904                  0
#
# [114 rows x 18 columns]

# %%
columns = ['URL_ID', 'URL', 'Title', 'Article','Positive_Score','Negative_score', 'Polarity_Score', 'Subjectivity_Score', 'Avg_Sentence_Length','Percentage_Of_Complex_word', 'Fog_index', 'Avg_No._Words/Sentence', 'complex_word_count','Word_count', 'syllable_count_per_word', 'Personal_Pronouns', 'Avg_word_length']
final = final_copy[columns]

# %%
final = final.rename(columns = {'complex_word_count':'Complex_word_count', 'syllable_count_per_word' : 'Syllable_count_per_word',  })

# %%
final
# Out:
#       URL_ID                                                URL  \
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#                                                  Title  \
# 0    Rise of telemedicine and its Impact on Livelih...
# 1    Rise of e-health and its impact on humans by t...
# 2                                                  NAN
# 3    Rise of telemedicine and its Impact on Livelih...
# 4    Rise of telemedicine and its Impact on Livelih...
# ..                                                 ...
# 109    Coronavirus: Impact on the Hospitality Industry
# 110               Coronavirus impact on energy markets
# 111  What are the key policies that will mitigate t...
# 112  Marketing Drives Results With A Focus On Problems
# 113                Continued Demand for Sustainability
#
#                                                Article  Positive_Score  \
# 0    Telemedicine,  use  technology  diagnose   pat...              81
# 1     rise  e-health,   use  electronic   facilitat...              41
# 2    2020     world  ravaged   SarsCov2 virus.  not...              22
# 3    “ gains  quality, affordability  accessibility...              41
# 4    “ gains  quality, affordability  accessibility...              41
# ..                                                 ...             ...
# 109   jumping   topic  would like  give  overview  ...               8
# 110    coronavirus spreads around  world  countries...              23
# 111   Alibaba     Google  , companies around  globe...              86
# 112  Whenthe  ruled ,  Indiansaccepted  work   poli...              26
# 113   business  business   longer    businessor inc...              51
#
#      Negative_score  Polarity_Score  Subjectivity_Score  Avg_Sentence_Length  \
# 0                21        0.588235            0.107937           144.852459
# 1                13        0.518519            0.165644           136.304348
# 2                27       -0.102041            0.080065            81.538462
# 3                26        0.223881            0.090663           126.313725
# 4                26        0.223881            0.090663           126.313725
# ..              ...             ...                 ...                  ...
# 109              26       -0.529412            0.093664           148.909091
# 110              58       -0.432099            0.088816           236.878788
# 111              32        0.457627            0.115347           128.686567
# 112              20        0.130435            0.061745           116.315789
# 113              24        0.360000            0.126904           157.111111
#
#      Percentage_Of_Complex_word  Fog_index  Avg_No._Words/Sentence  \
# 0                      0.588235   0.107937               15.491803
# 1                      0.518519   0.165644               14.173913
# 2                     -0.102041   0.080065                9.415385
# 3                      0.223881   0.090663               14.490196
# 4                      0.223881   0.090663               14.490196
# ..                          ...        ...                     ...
# 109                   -0.529412   0.093664               16.500000
# 110                   -0.432099   0.088816               27.818182
# 111                    0.457627   0.115347               15.268657
# 112                    0.130435   0.061745               13.122807
# 113                    0.360000   0.126904               16.416667
#
#      Complex_word_count  Word_count  Syllable_count_per_word  \
# 0                 261.0         945                 2.103704
# 1                 126.0         326                 2.343558
# 2                 192.0         612                 2.068627
# 3                 216.0         739                 2.037889
# 4                 216.0         739                 2.037889
# ..                  ...         ...                      ...
# 109                94.0         363                 2.013774
# 110               259.0         912                 1.990132
# 111               310.0        1023                 2.014663
# 112               211.0         745                 2.041611
# 113               248.0         591                 2.417936
#
#      Personal_Pronouns  Avg_word_length
# 0                    0         7.570370
# 1                    0         7.699387
# 2                    0         6.877451
# 3                    0         7.020298
# 4                    0         7.020298
# ..                 ...              ...
# 109                  0         7.115702
# 110                  0         6.682018
# 111                  0         6.642229
# 112                  1         6.995973
# 113                  0         7.871404
#
# [114 rows x 17 columns]
